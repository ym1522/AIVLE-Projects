# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
import numpy as np
import pandas as pd

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df17 = pd.read_csv('C:/Users/User/Desktop/미니프로젝트5차_생활인구 4_5일차/data2017.csv', sep=',', index_col=0)
df17
# Out:
#           시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  남자15세부터19세생활인구수  \
# 기준일ID
# 20170101      0  31535.2200      1945.4402         566.4588         631.5581
# 20170101      1  31188.9174      1930.4766         562.1018         625.2151
# 20170101      2  31240.4974      1921.1864         559.3965         658.7463
# 20170101      3  31442.4314      1946.4476         566.7525         649.0804
# 20170101      4  31922.7751      1953.7713         568.8845         623.2087
# ...         ...         ...            ...              ...              ...
# 20171231     19  38113.9642      2328.4174         677.9711         747.0057
# 20171231     20  37388.1990      2111.1139         614.6985         789.3426
# 20171231     21  36784.5323      2153.8616         627.1453         782.7005
# 20171231     22  37039.2231      2070.6344         602.9120         717.1471
# 20171231     23  36359.7592      2403.6778         699.8851         744.5285
#
# ...
